# %%
from CC import CC
from DnsVhost import DnsVhost
from MariaDB import MariaDB
from WP import WP
from Partition import Partition
from SMB import SMB
from NFS import NFS
from Diskquota import Diskquota
from ISCSI import ISCSI
from FTP import FTP
from RAID import RAID
from Tomcat import Tomcat
from Nginx import Nginx
from SNMP import SNMP
from Cacti import Cacti
from JL import JL

#---------------------------------------#
#             SSH 객체  생성             #
#---------------------------------------#
server_ip = "172.16.16.25"
server_account = "root"
server_passwd = "asd123!@"
cc =  CC(f"{server_ip}", f"{server_account}", f"{server_passwd}")
cc.connect()

#---------------------------------------#
#         여러 클래스 객체 생성            #
#---------------------------------------#
dv = DnsVhost("Rocky") 
mariadb = MariaDB()
wp = WP("Rocky")
part = Partition()
smb = SMB("Rocky")
nfs = NFS("Rocky")
dq = Diskquota("Rocky")
iscsi = ISCSI("Rocky","Rocky")
ftp = FTP("Rocky")
raid = RAID("Rocky")
tomcat = Tomcat("Rocky")
nginx = Nginx("Rocky")
snmp = SNMP("Rocky")
cacti = Cacti("Rocky")
jl = JL("Rocky")

#---------------------------------------#
#                 전역변수               #
#---------------------------------------#
ZONEFILE = ""


###################################################
#              HTTP,DNS -DnsVhost.py              #
###################################################
## 1. http, DNS 설치 및 초기 세팅 
def install_and_setting_http_dns() :
    #========= HTTP ========#
    cc.run(dv.install_http())
    dv.set_servername()
    cc.run(dv.mk_vhostconf())
    cc.run(dv.test_vhost())
    # web_dir,third_domain,error_log ,custom_log
    cc.run(dv.set_vhostconf("/home/test","test","/var/log/httpd/test_error.log","/var/log/httpd/test_access.log"))

    #========= DNS ========#
    cc.run(dv.install_named())
    cc.run(dv.init_set_named_conf())
    cc.run(dv.init_set_named_rfc())
    cc.run(dv.mk_zone_file())
    cc.run(dv.init_set_zone_file())
    cc.run(dv.set_dns_Third_domain("test"))

    #======= RESTART ========#
    cc.run(dv.restart_http())
    cc.run(dv.restart_dns())
    
## 2. 초기 세팅 이후에 새롭게 DnsVhost클래스 사용할 경우에 해당됨 (기본)
def mod_http_dns(web_dir,third_domain,error_log ,custom_log):
    dv.set_servername()
    #set_vhostconf(self,web_dir,third_domain,error_log ,custom_log):
    cc.run(dv.set_vhostconf(web_dir,third_domain,error_log ,custom_log))
    cc.run(f"mkdir -p {web_dir} && chmod 777 {web_dir}")
    cc.run(dv.set_dns_Third_domain(third_domain))
    cc.run(dv.restart_dns())
    cc.run(dv.restart_http())

## 3. 초기 세팅 이후에 새롭게 DnsVhost클래스 사용할 경우에 해당됨 (리버시 프록시)
def mod_http_dns_reverse_proxy(third_domain,error_log ,custom_log):
    dv.set_servername()
    #set_reverse_proxy_vhostconf(self,third_domain,error_log ,custom_log)
    cc.run(dv.set_reverse_proxy_vhostconf(third_domain,error_log ,custom_log))
    cc.run(dv.set_dns_Third_domain(third_domain))
    cc.run(dv.restart_dns())
    cc.run(dv.restart_http())
#---------------------실행부-----------------------#
#install_and_setting_http_dns()
#mod_http_dns("/home/test2/","test2","/var/log/httpd/test2_error.log","/var/log/httpd/test2_access.log")



###################################################
#            MariaDB,PHP -MariaDB.py              #
###################################################
## 1. mariaDB와 php 둘 다 설치함
def install_mariaDB_and_php():
    cc.run(mariadb.install_packages())
    cc.run(mariadb.install_apache_and_php())
    cc.run(mariadb.install_mariaDB())
    cc.run(mariadb.init_mariaDB())
    cc.run(mariadb.install_php_my_admin())
    cc.run(mariadb.set_phpMyadmin_conf())
    print("모든 설치 완료")
#---------------------실행부-----------------------#
#install_mariaDB_and_php()


##################################################
#           Partition -Partition.py              #
##################################################
def mk_partition():
    cc.run("lsblk")
    cc.run(part.make_partition())
    cc.run(part.format_partition())
    cc.run(part.mount())
    cc.run(part.permanent_mount_config_remote())


#---------------------실행부-----------------------#
#mk_partition()

###################################################
#                    SMB -SMB.py                  #
###################################################

def install_smb():
    cc.run(smb.smb_install())
    cc.run(smb.smb_intsll_status_check())   
    choose = input("smb 서버와 클라이언트 중 선택하세요.(S/C) ex)S : ")
    if(choose == "S" ) :
        server_smb()
    if(choose == "C" ) :
        client_smb()

def server_smb():
    cc.run(smb.smb_share_folder_make())
    cc.run(smb.smb_mk_smb_id())
    cc.run(smb.smb_set_smb_id_passwd())
    cc.run(smb.smb_id_check())
    cc.run(smb.smb_share_folder_authority())
    cc.run(smb.smb_mk_back())
    cc.run(smb.smb_set())
    cc.run(smb.smb_server_start())
    
def client_smb() :
    cc.run(smb.smb_client_login())
    cc.run(smb.smb_client_mount())
#---------------------실행부-----------------------#
#install_smb()

###################################################
#                    NFS -NFS.py                  #
###################################################

def install_nfs():
    cc.run(nfs.nfs_isntall())
    choose = input("NFS 서버와 클라이언트 중 선택하세요.(S/C) ex)S : ")
    if(choose == "S" ) :
        server_nfs()
    if(choose == "C" ) :
        client_nfs()

def server_nfs():
    cc.run(nfs.nfs_share_folder_make())
    cc.run(nfs.nfs_share_folder_authority())
    cc.run(nfs.server_nfs_set_exports_config())
    cc.run(nfs.server_nfs_start())

def client_nfs():
    cc.run(nfs.nfs_client_mount_temporary())
    cc.run(nfs.nfs_clinet_mount_permanent())
#---------------------실행부-----------------------#
#install_nfs()

###################################################
#            Diskquota -diskquota.py              #
###################################################
def diskquota_install_and_set():
    cc.run(dq.diskquota_isntall())
    cc.run(dq.diskquota_install_check())
    cc.run("lsblk")
    print("TYPE MOUNTPOINTS가 part로 되어있는 디스크만 가능합니다. 안되면 partition을 해야합니다")
    exist_part = input("part로 되어있는 디스크가 없으시거나 해당 디스크가 마운트가 안되어있는 경우에 반드시 n 입력해주세요.\n 있으시면 y 또는 아무문자열 입력 ex) y: ")
    if(exist_part == "n") :
        return
    cc.run(dq.diskquota_modify())
    cc.run(dq.diskquota_mount_and_initalization())
    cc.run(dq.diskquota_settings())
    cc.run(dq.diskquota_systemctl())
    
#---------------------실행부-----------------------#
#diskquota_install_and_set()



###################################################
#                  ISCSI -ISCSI.py                #
###################################################
def iscsi_all_in_one():

    #=========== server 영역 ===========#
    #cc.run(iscsi.set_firewall())
    cc.run(iscsi.install_target())
    
    #=========== client 영역 ===========#
    client_ip = input("새로운 SSH 연결을 합니다. 클라이언트 IP를 입력하세요")
    client_account = input("클라이언트 계정 입력하세요 ex. root")
    client_passwd = input("클라이언트 계정의 비밀번호를 입력하세요 ex. asd123!@")
    cc_client =  CC(f"{client_ip}", f"{client_account}", f"{client_passwd}")
    cc_client.connect()
    
    cc_client.run(iscsi.iscsi_client_install())
    cc_client.run(iscsi.iscsi_client_iqn())
    iscsi_client_iqn_domain = input("위에서 확인 CLIENT의 IQN을 복사해주세요")

    #=========== server 영역 ===========#
    print("[ISCSI 서버] ISCSI 서버를 세팅해보겠습니다.")
    cc.run("lsblk")
    disk_path = input("위의 결과를 확인하시고 iSCSI로 제공할 디스크 경로를 입력하세요 : ex)/dev/sdb")
    cc.run(iscsi.targetcli(server_ip, iscsi_client_iqn_domain, disk_path))

    #=========== client 영역 ===========#
    print("[ISCSI 클라이언트] ISCSI 클라이언트를 세팅해보겠습니다.")
    cc_client.run(iscsi.iscsi_client_login_set_servers_iscsi(server_ip))
    cc_client.run("iscsiadm -m session")
    print("이제 클라이언트로 돌아가셔서 lsblk로 확인해보세요. 또 iscsiadm -m session로 잘 받았는지 확인해보세요 ^^")
    print("[ISCSI] 모든 설정 및 세팅이 완료되었습니다.")
#---------------------실행부-----------------------#
#iscsi_all_in_one()

###################################################
#                    FTP -FTP.py                  #
###################################################
def inital_FTP():
    print("[FTP 서버] FTP 설치 및 유저를 생성합니다.")
    cc.run(ftp.install_ftp())
    cc.run(ftp.on_off_ftp())
    cc.run(ftp.set_ftp_config())
    cc.run(ftp.add_ftpuser())
    cc.run(ftp.set_ftpuser_passwd())
    cc.run(ftp.set_dir())
    print("[FTP 서버] 설치 및 설정이 완료되었습니다. ")
#---------------------실행부-----------------------#
#inital_FTP()

###################################################
#                  RAID -RAID.py                  #
###################################################
def mk_raid1():
    print("[RAID] RAID1을 만듭니다.")
    cc.run(raid.install_raid())
    cc.run("lsblk")
    cc.run(raid.raid1_mk())
    cc.run(raid.raid1_mk_fs_mount())
    permanent_mount = input("영구마운트 하겠습니까 yes or no (ex. yes) : ")    
    if(permanent_mount == "yes") :
        cc.run(raid.raid1_permanent_mount_config_remote())
    print("완료 했습니다!")
    cc.run("lsblk")
    
def erase_raid():
    print("[RAID] RAID를 제거합니다.")
    cc.run("lsblk")
    cc.run(raid.erase_raid())
    cc.run("lsblk")
    print("RAID가 제거되었습니다 ^^")
    
#---------------------실행부-----------------------#
#mk_raid1()
#erase_raid()


###################################################
#               Tomcat -Tomcat.py                 #
###################################################
def install_tomcat():
    print("[Tomcat] 설치하겠습니다.")
    cc.run(tomcat.install_java())
    cc.run(tomcat.set_tomcat())
  #  mod_http_dns_reverse_proxy(web_dir,third_domain,error_log ,custom_log):
    mod_http_dns_reverse_proxy("tom","/var/log/httpd/tom_error_log", "/var/log/httpd/tom_access_log")
    cc.run(tomcat.set_service())
    print("[Tomcat] 설치 및 설정이 완료되었습니다.")

#---------------------실행부-----------------------#
#install_tomcat()

###################################################
#                 WP,PHPMYSQL -WP.py              #
###################################################
## 1. 로컬) WP 설치 및 wp-config.php 파일 수정까지
def install_wp():
    print("[WP] 설치하겠습니다.")
    print("[전제조건] mariaDB가 있어야하며, 서버팀에게 wp를 위한 유저 및 db를 생성해야합니다.")
    cc.run(wp.install_prev_packages())
    cc.run(wp.install_and_move_dir())
    cc.run(wp.set_wp_config_php_client())
    #def mod_http_dns(web_dir,third_domain,error_log ,custom_log):
    mod_http_dns("/home/wp","wp","/var/log/httpd/wp_error_log", "/var/log/httpd/wp_access_log")
    print("[WP] 설치 및 설정이 완료되었습니다.")
#---------------------실행부-----------------------#
#install_wp()

###################################################
#                  Nginx -Nginx.py                #
###################################################
## 1. 로컬) WP 설치 및 wp-config.php 파일 수정까지
def install_nginx():
    print("[Nginx] 설치하겠습니다.")
    print("[전제조건] httpd, dns, php, wp(시범용)가 있어야합니다. ")
    cc.run(nginx.install_nginx())
    servername = input("server name 입력 ex. test.com , ppp.com : ")
    cc.run(nginx.set_vhostconf(servername))
    cc.run(nginx.restart_nginx())
    print("[Nginx] 설치 및 설정이 완료되었습니다.")
#---------------------실행부-----------------------#
#install_nginx()


###################################################
#                  Nginx -Nginx.py                #
###################################################
## 1. 로컬) WP 설치 및 wp-config.php 파일 수정까지
def install_snmp():
    print("[SNMP] 설치하겠습니다.")
    print("[전제조건] Rocky는 dnf있어야함. ")
    cc.run(snmp.install_snmp())
    cc.run(snmp.set_snmp())
    cc.run(snmp.start_enable_snmpd())
    cc.run(snmp.test_snmpd_local())
    print("[SNMP] 설정 완료")
    
#---------------------실행부-----------------------#
#install_snmp()

###################################################
#                  Cacti -Cacti.py                #
###################################################
## 1. 로컬) WP 설치 및 wp-config.php 파일 수정까지
def install_cacti():
    print("[Cacti] 설치하겠습니다.")
    print("[전제조건] MRTG 있어야함. ")
    cc.run(cacti.install_cacti())
    cc.run(cacti.set_mariadb_server_cnf())
    cc.run(cacti.set_cacti())
    cc.run(cacti.set_cacti_db_php())
    cc.run(cacti.set_cacti_conf())
    cc.run(cacti.restart_all())

    print("#======= timezone 세팅 시작합니다. =========#")
    cc.run(cacti.set_my_cnf())
    cc.run(cacti.set_timezone())
    cc.run(cacti.grant_timezone_to_user())
    cc.run(cacti.set_php_ini())
    cc.run(cacti.restart_all())

    print("#======= cron.d 세팅 시작합니다. =========#")
    cc.run(cacti.set_crond())
    
    print("[Cacti] 설정 완료")
    print("이제 브라우저에 접속해주세요.") 
    print("1. [초기 세팅] username : admin , password : admin 입니다.")
    print("2. [Change Password] current password : admin , New password : Asd123!@ 입니다.")
    
#---------------------실행부-----------------------#
#install_cacti()

###################################################
#                    JL -JL.py                    #
###################################################
## 1. 로컬) WP 설치 및 wp-config.php 파일 수정까지
def install_JL():
    print("[JL] 설치하겠습니다.")
    print("[전제조건] MariaDB JL용 계정 및 JL DB 있어야함. ")
    cc.run(jl.install_pacakages())
    cc.run(jl.install_JL())
#def mod_http_dns(web_dir,third_domain,error_log ,custom_log):
    mod_http_dns("/home/jl","jl","/var/log/httpd/jl_error_log", "/var/log/httpd/jl_access_log")
    print("[JL] 설정 완료")

#---------------------실행부-----------------------#
install_JL()
# Out:
# 실행
# MariaDB init start
# WP init 시작
# [JL] 설치하겠습니다.
# [전제조건] MariaDB JL용 계정 및 JL DB 있어야함.
# Rocky Linux 9 - BaseOS                          6.2 kB/s | 4.3 kB     00:00
# Rocky Linux 9 - AppStream                       7.8 kB/s | 4.8 kB     00:00
# Rocky Linux 9 - CRB                             8.2 kB/s | 4.8 kB     00:00
# Rocky Linux 9 - Extras                          5.3 kB/s | 3.1 kB     00:00
# Package unzip-6.0-59.el9.x86_64 is already installed.
# Dependencies resolved.
# Nothing to do.
# Complete!
#
# --2025-12-27 22:36:27--  https://downloads.joomla.org/cms/joomla6/6-0-0/Joomla_6-0-0-Stable-Full_Package.zip?format=zip
# Resolving downloads.joomla.org (downloads.joomla.org)... 172.67.74.86, 104.26.15.15, 104.26.14.15, ...
# Connecting to downloads.joomla.org (downloads.joomla.org)|172.67.74.86|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://update.joomla.org/releases/6.0.0/Joomla_6.0.0-Stable-Full_Package.zip [following]
# --2025-12-27 22:36:28--  https://update.joomla.org/releases/6.0.0/Joomla_6.0.0-Stable-Full_Package.zip
# Resolving update.joomla.org (update.joomla.org)... 172.67.74.86, 104.26.15.15, 104.26.14.15, ...
# Connecting to update.joomla.org (update.joomla.org)|172.67.74.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32555090 (31M) [application/zip]
# Saving to: ‘Joomla_6-0-0-Stable-Full_Package.zip?format=zip’
#
# Joomla_6-0-0-Stable 100%[===================>]  31.05M  6.74MB/s    in 5.5s
#
# 2025-12-27 22:36:34 (5.60 MB/s) - ‘Joomla_6-0-0-Stable-Full_Package.zip?format=zip’ saved [32555090/32555090]
#
# Archive:  Joomla_6-0-0-Stable-Full_Package.zip?format=zip
#   inflating: LICENSE.txt
#   inflating: README.txt
#    creating: administrator/
#    creating: administrator/includes/
#   inflating: administrator/includes/framework.php
#   inflating: administrator/includes/defines.php
#   inflating: administrator/includes/app.php
#    creating: administrator/language/
#    creating: administrator/language/overrides/
#   inflating: administrator/language/overrides/index.html
#    creating: administrator/language/en-GB/
#   inflating: administrator/language/en-GB/plg_task_sitestatus.sys.ini
#   inflating: administrator/language/en-GB/plg_content_finder.ini
#   inflating: administrator/language/en-GB/plg_user_terms.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_article.sys.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_tags_steps.ini
#   inflating: administrator/language/en-GB/plg_system_log.sys.ini
#   inflating: administrator/language/en-GB/com_media.sys.ini
#   inflating: administrator/language/en-GB/plg_task_requests.ini
#   inflating: administrator/language/en-GB/mod_title.ini
#   inflating: administrator/language/en-GB/plg_fields_note.sys.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_guidedtours.ini
#   inflating: administrator/language/en-GB/plg_webservices_content.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_text.sys.ini
#   inflating: administrator/language/en-GB/mod_custom.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_newsfeeds_steps.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_welcome.ini
#   inflating: administrator/language/en-GB/com_menus.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_tags.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_contact.ini
#   inflating: administrator/language/en-GB/plg_webservices_privacy.ini
#   inflating: administrator/language/en-GB/com_mails.ini
#   inflating: administrator/language/en-GB/plg_privacy_content.sys.ini
#   inflating: administrator/language/en-GB/plg_task_deleteactionlogs.ini
#   inflating: administrator/language/en-GB/plg_workflow_notification.sys.ini
#   inflating: administrator/language/en-GB/mod_sampledata.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_custom.sys.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_article.sys.ini
#   inflating: administrator/language/en-GB/plg_installer_packageinstaller.sys.ini
#   inflating: administrator/language/en-GB/mod_login.ini
#   inflating: administrator/language/en-GB/plg_editors_codemirror.sys.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_article.ini
#   inflating: administrator/language/en-GB/com_tags.sys.ini
#   inflating: administrator/language/en-GB/plg_privacy_actionlogs.ini
#   inflating: administrator/language/en-GB/plg_sampledata_blog.ini
#   inflating: administrator/language/en-GB/plg_webservices_tags.ini
#   inflating: administrator/language/en-GB/plg_webservices_messages.ini
#   inflating: administrator/language/en-GB/com_cache.sys.ini
#   inflating: administrator/language/en-GB/plg_user_contactcreator.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_banners_steps.ini
#   inflating: administrator/language/en-GB/plg_content_loadmodule.ini
#   inflating: administrator/language/en-GB/plg_finder_tags.ini
#   inflating: administrator/language/en-GB/plg_webservices_users.ini
#   inflating: administrator/language/en-GB/plg_system_logout.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_whatsnew_6_0.ini
#   inflating: administrator/language/en-GB/plg_behaviour_versionable.sys.ini
#   inflating: administrator/language/en-GB/plg_multifactorauth_fixed.ini
#   inflating: administrator/language/en-GB/plg_system_privacyconsent.sys.ini
#   inflating: administrator/language/en-GB/plg_authentication_cookie.sys.ini
#   inflating: administrator/language/en-GB/com_messages.sys.ini
#   inflating: administrator/language/en-GB/plg_webservices_languages.sys.ini
#   inflating: administrator/language/en-GB/localise.php
#   inflating: administrator/language/en-GB/plg_content_contact.ini
#   inflating: administrator/language/en-GB/com_redirect.ini
#   inflating: administrator/language/en-GB/plg_content_pagebreak.sys.ini
#   inflating: administrator/language/en-GB/com_installer.ini
#   inflating: administrator/language/en-GB/mod_submenu.ini
#   inflating: administrator/language/en-GB/plg_workflow_featuring.ini
#   inflating: administrator/language/en-GB/plg_user_token.sys.ini
#   inflating: administrator/language/en-GB/plg_user_profile.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_users_steps.ini
#   inflating: administrator/language/en-GB/plg_actionlog_joomla.sys.ini
#   inflating: administrator/language/en-GB/plg_finder_categories.ini
#   inflating: administrator/language/en-GB/com_joomlaupdate.ini
#   inflating: administrator/language/en-GB/com_finder.ini
#   inflating: administrator/language/en-GB/plg_quickicon_joomlaupdate.ini
#   inflating: administrator/language/en-GB/com_newsfeeds.sys.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_guidedtours_steps.ini
#   inflating: administrator/language/en-GB/plg_sampledata_multilang.ini
#   inflating: administrator/language/en-GB/plg_task_deleteactionlogs.sys.ini
#   inflating: administrator/language/en-GB/plg_quickicon_phpversioncheck.sys.ini
#   inflating: administrator/language/en-GB/plg_authentication_joomla.ini
#   inflating: administrator/language/en-GB/com_postinstall.ini
#   inflating: administrator/language/en-GB/plg_content_pagenavigation.ini
#   inflating: administrator/language/en-GB/plg_system_debug.ini
#   inflating: administrator/language/en-GB/plg_user_joomla.ini
#   inflating: administrator/language/en-GB/com_wrapper.ini
#   inflating: administrator/language/en-GB/plg_api-authentication_token.sys.ini
#   inflating: administrator/language/en-GB/plg_extension_joomlaupdate.ini
#   inflating: administrator/language/en-GB/install.xml
#   inflating: administrator/language/en-GB/plg_webservices_menus.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_categories_steps.ini
#   inflating: administrator/language/en-GB/plg_task_sessiongc.sys.ini
#   inflating: administrator/language/en-GB/plg_finder_contacts.sys.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_banners.ini
#   inflating: administrator/language/en-GB/plg_webservices_installer.sys.ini
#   inflating: administrator/language/en-GB/plg_sampledata_blog.sys.ini
#   inflating: administrator/language/en-GB/mod_privacy_status.ini
#   inflating: administrator/language/en-GB/mod_user.ini
#   inflating: administrator/language/en-GB/plg_api-authentication_token.ini
#   inflating: administrator/language/en-GB/plg_authentication_cookie.ini
#   inflating: administrator/language/en-GB/plg_editors_none.ini
#   inflating: administrator/language/en-GB/plg_fields_radio.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_menus_steps.ini
#   inflating: administrator/language/en-GB/plg_webservices_joomlaupdate.sys.ini
#   inflating: administrator/language/en-GB/mod_post_installation_messages.sys.ini
#   inflating: administrator/language/en-GB/plg_webservices_templates.sys.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_welcome_steps.ini
#   inflating: administrator/language/en-GB/com_associations.sys.ini
#   inflating: administrator/language/en-GB/plg_task_globalcheckin.ini
#   inflating: administrator/language/en-GB/plg_sampledata_multilang.sys.ini
#   inflating: administrator/language/en-GB/plg_quickicon_overridecheck.sys.ini
#   inflating: administrator/language/en-GB/plg_filesystem_local.sys.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_article.ini
#   inflating: administrator/language/en-GB/plg_authentication_ldap.sys.ini
#   inflating: administrator/language/en-GB/mod_stats_admin.ini
#   inflating: administrator/language/en-GB/plg_fields_sql.sys.ini
#   inflating: administrator/language/en-GB/mod_login.sys.ini
#   inflating: administrator/language/en-GB/mod_title.sys.ini
#   inflating: administrator/language/en-GB/plg_editors_codemirror.ini
#   inflating: administrator/language/en-GB/plg_quickicon_autoupdate.sys.ini
#   inflating: administrator/language/en-GB/plg_system_cache.ini
#   inflating: administrator/language/en-GB/plg_content_loadmodule.sys.ini
#   inflating: administrator/language/en-GB/plg_user_joomla.sys.ini
#   inflating: administrator/language/en-GB/mod_guidedtours.sys.ini
#   inflating: administrator/language/en-GB/plg_system_highlight.sys.ini
#   inflating: administrator/language/en-GB/plg_system_logout.sys.ini
#   inflating: administrator/language/en-GB/com_admin.ini
#   inflating: administrator/language/en-GB/mod_quickicon.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_recipe.sys.ini
#   inflating: administrator/language/en-GB/plg_extension_finder.ini
#   inflating: administrator/language/en-GB/plg_fields_integer.sys.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_image.sys.ini
#   inflating: administrator/language/en-GB/plg_webservices_banners.ini
#   inflating: administrator/language/en-GB/plg_fields_textarea.sys.ini
#   inflating: administrator/language/en-GB/com_banners.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_url.sys.ini
#   inflating: administrator/language/en-GB/com_content.ini
#   inflating: administrator/language/en-GB/plg_task_privacyconsent.sys.ini
#   inflating: administrator/language/en-GB/plg_webservices_users.sys.ini
#   inflating: administrator/language/en-GB/plg_webservices_config.sys.ini
#   inflating: administrator/language/en-GB/plg_installer_urlinstaller.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_usergrouplist.sys.ini
#   inflating: administrator/language/en-GB/plg_system_actionlogs.sys.ini
#   inflating: administrator/language/en-GB/plg_media-action_crop.sys.ini
#   inflating: administrator/language/en-GB/mod_version.ini
#   inflating: administrator/language/en-GB/plg_system_skipto.sys.ini
#   inflating: administrator/language/en-GB/mod_loginsupport.ini
#   inflating: administrator/language/en-GB/mod_post_installation_messages.ini
#   inflating: administrator/language/en-GB/plg_system_fields.sys.ini
#   inflating: administrator/language/en-GB/plg_content_fields.sys.ini
#   inflating: administrator/language/en-GB/plg_workflow_featuring.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_note.ini
#   inflating: administrator/language/en-GB/com_redirect.sys.ini
#   inflating: administrator/language/en-GB/plg_task_globalcheckin.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_user.sys.ini
#   inflating: administrator/language/en-GB/plg_authentication_joomla.sys.ini
#   inflating: administrator/language/en-GB/plg_finder_content.sys.ini
#   inflating: administrator/language/en-GB/plg_system_httpheaders.sys.ini
#   inflating: administrator/language/en-GB/plg_extension_joomla.sys.ini
#   inflating: administrator/language/en-GB/plg_installer_urlinstaller.ini
#   inflating: administrator/language/en-GB/plg_webservices_plugins.sys.ini
#   inflating: administrator/language/en-GB/plg_system_webauthn.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_jobposting.ini
#   inflating: administrator/language/en-GB/plg_media-action_resize.sys.ini
#   inflating: administrator/language/en-GB/plg_system_redirect.ini
#   inflating: administrator/language/en-GB/plg_webservices_templates.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_book.ini
#   inflating: administrator/language/en-GB/com_cpanel.sys.ini
#   inflating: administrator/language/en-GB/plg_privacy_user.sys.ini
#   inflating: administrator/language/en-GB/mod_popular.sys.ini
#   inflating: administrator/language/en-GB/plg_multifactorauth_yubikey.ini
#   inflating: administrator/language/en-GB/com_checkin.ini
#   inflating: administrator/language/en-GB/plg_webservices_tags.sys.ini
#   inflating: administrator/language/en-GB/plg_task_rotatelogs.sys.ini
#   inflating: administrator/language/en-GB/plg_media-action_rotate.sys.ini
#   inflating: administrator/language/en-GB/plg_system_schemaorg.ini
#   inflating: administrator/language/en-GB/plg_fields_user.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_image.ini
#   inflating: administrator/language/en-GB/plg_system_schemaorg.sys.ini
#   inflating: administrator/language/en-GB/plg_content_emailcloak.ini
#   inflating: administrator/language/en-GB/plg_fields_url.ini
#   inflating: administrator/language/en-GB/plg_quickicon_overridecheck.ini
#   inflating: administrator/language/en-GB/plg_installer_override.sys.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_recipe.ini
#   inflating: administrator/language/en-GB/plg_multifactorauth_totp.sys.ini
#   inflating: administrator/language/en-GB/plg_task_updatenotification.ini
#   inflating: administrator/language/en-GB/com_associations.ini
#   inflating: administrator/language/en-GB/mod_submenu.sys.ini
#   inflating: administrator/language/en-GB/com_contenthistory.sys.ini
#   inflating: administrator/language/en-GB/plg_task_updatenotification.sys.ini
#   inflating: administrator/language/en-GB/plg_installer_override.ini
#   inflating: administrator/language/en-GB/plg_fields_media.ini
#   inflating: administrator/language/en-GB/plg_api-authentication_basic.ini
#   inflating: administrator/language/en-GB/plg_task_sessiongc.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_event.sys.ini
#   inflating: administrator/language/en-GB/com_joomlaupdate.sys.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_fields.ini
#   inflating: administrator/language/en-GB/plg_privacy_actionlogs.sys.ini
#   inflating: administrator/language/en-GB/plg_privacy_contact.ini
#   inflating: administrator/language/en-GB/plg_webservices_config.ini
#   inflating: administrator/language/en-GB/plg_user_profile.sys.ini
#   inflating: administrator/language/en-GB/mod_messages.sys.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_pagebreak.ini
#   inflating: administrator/language/en-GB/plg_webservices_newsfeeds.sys.ini
#   inflating: administrator/language/en-GB/com_modules.sys.ini
#   inflating: administrator/language/en-GB/mod_custom.sys.ini
#   inflating: administrator/language/en-GB/mod_stats_admin.sys.ini
#   inflating: administrator/language/en-GB/plg_system_languagecode.ini
#   inflating: administrator/language/en-GB/plg_fields_text.ini
#   inflating: administrator/language/en-GB/com_config.ini
#   inflating: administrator/language/en-GB/plg_system_jooa11y.sys.ini
#   inflating: administrator/language/en-GB/plg_content_confirmconsent.sys.ini
#   inflating: administrator/language/en-GB/plg_content_vote.sys.ini
#   inflating: administrator/language/en-GB/plg_quickicon_downloadkey.ini
#   inflating: administrator/language/en-GB/com_plugins.sys.ini
#   inflating: administrator/language/en-GB/com_guidedtours.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_color.sys.ini
#   inflating: administrator/language/en-GB/com_content.sys.ini
#   inflating: administrator/language/en-GB/plg_privacy_message.sys.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_smartsearch.ini
#   inflating: administrator/language/en-GB/com_finder.sys.ini
#   inflating: administrator/language/en-GB/com_modules.ini
#   inflating: administrator/language/en-GB/mod_quickicon.sys.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_articles_steps.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_guidedtoursteps_steps.ini
#   inflating: administrator/language/en-GB/plg_fields_media.sys.ini
#   inflating: administrator/language/en-GB/plg_finder_tags.sys.ini
#   inflating: administrator/language/en-GB/plg_webservices_contact.ini
#   inflating: administrator/language/en-GB/plg_system_highlight.ini
#   inflating: administrator/language/en-GB/com_tags.ini
#   inflating: administrator/language/en-GB/plg_user_token.ini
#   inflating: administrator/language/en-GB/plg_system_privacyconsent.ini
#   inflating: administrator/language/en-GB/com_banners.ini
#   inflating: administrator/language/en-GB/plg_editors_none.sys.ini
#   inflating: administrator/language/en-GB/plg_content_pagebreak.ini
#   inflating: administrator/language/en-GB/plg_webservices_languages.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_whatsnew_6_0_steps.ini
#   inflating: administrator/language/en-GB/plg_webservices_menus.sys.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_book.sys.ini
#   inflating: administrator/language/en-GB/mod_messages.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_contact.sys.ini
#   inflating: administrator/language/en-GB/plg_task_requests.sys.ini
#   inflating: administrator/language/en-GB/com_scheduler.ini
#   inflating: administrator/language/en-GB/com_guidedtours.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_readmore.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_menu.sys.ini
#   inflating: administrator/language/en-GB/plg_system_guidedtours.sys.ini
#   inflating: administrator/language/en-GB/plg_editors_tinymce.sys.ini
#   inflating: administrator/language/en-GB/com_admin.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_textarea.ini
#   inflating: administrator/language/en-GB/plg_webservices_newsfeeds.ini
#   inflating: administrator/language/en-GB/mod_logged.sys.ini
#   inflating: administrator/language/en-GB/plg_system_fields.ini
#   inflating: administrator/language/en-GB/plg_fields_number.ini
#   inflating: administrator/language/en-GB/plg_webservices_joomlaupdate.ini
#   inflating: administrator/language/en-GB/plg_fields_subform.ini
#   inflating: administrator/language/en-GB/plg_webservices_redirect.ini
#   inflating: administrator/language/en-GB/com_actionlogs.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_custom.ini
#   inflating: administrator/language/en-GB/plg_quickicon_privacycheck.ini
#   inflating: administrator/language/en-GB/plg_finder_categories.sys.ini
#   inflating: administrator/language/en-GB/mod_latest.ini
#   inflating: administrator/language/en-GB/plg_behaviour_compat6.ini
#   inflating: administrator/language/en-GB/plg_webservices_modules.sys.ini
#   inflating: administrator/language/en-GB/mod_feed.ini
#   inflating: administrator/language/en-GB/plg_webservices_installer.ini
#   inflating: administrator/language/en-GB/com_login.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_readmore.sys.ini
#   inflating: administrator/language/en-GB/com_media.ini
#   inflating: administrator/language/en-GB/plg_webservices_redirect.sys.ini
#   inflating: administrator/language/en-GB/plg_multifactorauth_webauthn.ini
#   inflating: administrator/language/en-GB/plg_quickicon_downloadkey.sys.ini
#   inflating: administrator/language/en-GB/plg_content_joomla.sys.ini
#   inflating: administrator/language/en-GB/com_menus.sys.ini
#   inflating: administrator/language/en-GB/plg_system_stats.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_editor.sys.ini
#   inflating: administrator/language/en-GB/com_postinstall.sys.ini
#   inflating: administrator/language/en-GB/lib_joomla.ini
#   inflating: administrator/language/en-GB/plg_content_contact.sys.ini
#   inflating: administrator/language/en-GB/plg_quickicon_extensionupdate.sys.ini
#   inflating: administrator/language/en-GB/plg_system_log.ini
#   inflating: administrator/language/en-GB/com_templates.sys.ini
#   inflating: administrator/language/en-GB/plg_quickicon_autoupdate.ini
#   inflating: administrator/language/en-GB/plg_privacy_content.ini
#   inflating: administrator/language/en-GB/plg_quickicon_eos.sys.ini
#   inflating: administrator/language/en-GB/plg_api-authentication_basic.sys.ini
#   inflating: administrator/language/en-GB/com_languages.sys.ini
#   inflating: administrator/language/en-GB/plg_behaviour_taggable.sys.ini
#   inflating: administrator/language/en-GB/mod_latestactions.ini
#   inflating: administrator/language/en-GB/com_login.sys.ini
#   inflating: administrator/language/en-GB/plg_system_guidedtours.ini
#   inflating: administrator/language/en-GB/tpl_atum.ini
#   inflating: administrator/language/en-GB/plg_content_joomla.ini
#   inflating: administrator/language/en-GB/plg_webservices_contact.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_number.sys.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_menus.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_newsfeeds.ini
#   inflating: administrator/language/en-GB/langmetadata.xml
#   inflating: administrator/language/en-GB/plg_fields_imagelist.sys.ini
#   inflating: administrator/language/en-GB/mod_frontend.sys.ini
#   inflating: administrator/language/en-GB/mod_loginsupport.sys.ini
#   inflating: administrator/language/en-GB/com_newsfeeds.ini
#   inflating: administrator/language/en-GB/mod_logged.ini
#   inflating: administrator/language/en-GB/plg_content_confirmconsent.ini
#   inflating: administrator/language/en-GB/plg_system_sef.ini
#   inflating: administrator/language/en-GB/com_ajax.sys.ini
#   inflating: administrator/language/en-GB/plg_webservices_modules.ini
#   inflating: administrator/language/en-GB/mod_latest.sys.ini
#   inflating: administrator/language/en-GB/plg_privacy_user.ini
#   inflating: administrator/language/en-GB/plg_system_redirect.sys.ini
#   inflating: administrator/language/en-GB/com_installer.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_calendar.ini
#   inflating: administrator/language/en-GB/mod_sampledata.sys.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_module.sys.ini
#   inflating: administrator/language/en-GB/plg_privacy_consents.sys.ini
#   inflating: administrator/language/en-GB/com_users.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_menu.ini
#   inflating: administrator/language/en-GB/mod_feed.sys.ini
#   inflating: administrator/language/en-GB/plg_system_languagefilter.sys.ini
#   inflating: administrator/language/en-GB/plg_quickicon_phpversioncheck.ini
#   inflating: administrator/language/en-GB/plg_system_shortcut.sys.ini
#   inflating: administrator/language/en-GB/com_actionlogs.sys.ini
#   inflating: administrator/language/en-GB/plg_extension_finder.sys.ini
#   inflating: administrator/language/en-GB/joomla.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_blogposting.sys.ini
#   inflating: administrator/language/en-GB/plg_privacy_consents.ini
#   inflating: administrator/language/en-GB/plg_system_accessibility.sys.ini
#   inflating: administrator/language/en-GB/plg_webservices_media.sys.ini
#   inflating: administrator/language/en-GB/plg_content_pagenavigation.sys.ini
#   inflating: administrator/language/en-GB/mod_user.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_subform.sys.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_person.ini
#   inflating: administrator/language/en-GB/plg_system_schedulerunner.sys.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_event.ini
#   inflating: administrator/language/en-GB/mod_multilangstatus.sys.ini
#   inflating: administrator/language/en-GB/plg_system_debug.sys.ini
#   inflating: administrator/language/en-GB/plg_system_shortcut.ini
#   inflating: administrator/language/en-GB/plg_content_finder.sys.ini
#   inflating: administrator/language/en-GB/plg_system_languagefilter.ini
#   inflating: administrator/language/en-GB/plg_media-action_rotate.ini
#   inflating: administrator/language/en-GB/mod_latestactions.sys.ini
#   inflating: administrator/language/en-GB/plg_editors_tinymce.ini
#   inflating: administrator/language/en-GB/tpl_atum.sys.ini
#   inflating: administrator/language/en-GB/plg_system_jooa11y.ini
#   inflating: administrator/language/en-GB/plg_installer_folderinstaller.sys.ini
#   inflating: administrator/language/en-GB/com_mails.sys.ini
#   inflating: administrator/language/en-GB/plg_quickicon_privacycheck.sys.ini
#   inflating: administrator/language/en-GB/plg_system_httpheaders.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_articles.ini
#   inflating: administrator/language/en-GB/com_users.sys.ini
#   inflating: administrator/language/en-GB/plg_workflow_notification.ini
#   inflating: administrator/language/en-GB/mod_frontend.ini
#   inflating: administrator/language/en-GB/plg_fields_list.sys.ini
#   inflating: administrator/language/en-GB/plg_multifactorauth_fixed.sys.ini
#   inflating: administrator/language/en-GB/com_categories.sys.ini
#   inflating: administrator/language/en-GB/plg_finder_contacts.ini
#   inflating: administrator/language/en-GB/mod_toolbar.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_checkboxes.sys.ini
#   inflating: administrator/language/en-GB/com_contact.ini
#   inflating: administrator/language/en-GB/mod_privacy_dashboard.sys.ini
#   inflating: administrator/language/en-GB/plg_actionlog_joomla.ini
#   inflating: administrator/language/en-GB/plg_quickicon_eos.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_blogposting.ini
#   inflating: administrator/language/en-GB/com_contenthistory.ini
#   inflating: administrator/language/en-GB/plg_user_terms.sys.ini
#   inflating: administrator/language/en-GB/plg_system_sef.sys.ini
#   inflating: administrator/language/en-GB/plg_installer_webinstaller.sys.ini
#   inflating: administrator/language/en-GB/plg_finder_content.ini
#   inflating: administrator/language/en-GB/plg_system_tasknotification.ini
#   inflating: administrator/language/en-GB/plg_extension_namespacemap.ini
#   inflating: administrator/language/en-GB/plg_extension_joomlaupdate.sys.ini
#   inflating: administrator/language/en-GB/plg_media-action_crop.ini
#   inflating: administrator/language/en-GB/plg_multifactorauth_totp.ini
#   inflating: administrator/language/en-GB/plg_webservices_content.ini
#   inflating: administrator/language/en-GB/com_templates.ini
#   inflating: administrator/language/en-GB/plg_authentication_ldap.ini
#   inflating: administrator/language/en-GB/plg_system_stats.ini
#   inflating: administrator/language/en-GB/mod_multilangstatus.ini
#   inflating: administrator/language/en-GB/com_categories.ini
#   inflating: administrator/language/en-GB/com_cache.ini
#   inflating: administrator/language/en-GB/plg_fields_integer.ini
#   inflating: administrator/language/en-GB/com_fields.sys.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_jobposting.sys.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_guidedtoursteps.ini
#   inflating: administrator/language/en-GB/com_languages.ini
#   inflating: administrator/language/en-GB/plg_task_sitestatus.ini
#   inflating: administrator/language/en-GB/plg_system_remember.sys.ini
#   inflating: administrator/language/en-GB/com_privacy.sys.ini
#   inflating: administrator/language/en-GB/com_workflow.ini
#   inflating: administrator/language/en-GB/plg_webservices_messages.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_radio.sys.ini
#   inflating: administrator/language/en-GB/plg_privacy_message.ini
#   inflating: administrator/language/en-GB/plg_webservices_plugins.ini
#   inflating: administrator/language/en-GB/plg_installer_folderinstaller.ini
#   inflating: administrator/language/en-GB/plg_behaviour_taggable.ini
#   inflating: administrator/language/en-GB/plg_quickicon_extensionupdate.ini
#   inflating: administrator/language/en-GB/mod_version.sys.ini
#   inflating: administrator/language/en-GB/plg_system_tasknotification.sys.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_pagebreak.sys.ini
#   inflating: administrator/language/en-GB/plg_quickicon_joomlaupdate.sys.ini
#   inflating: administrator/language/en-GB/plg_system_cache.sys.ini
#   inflating: administrator/language/en-GB/plg_behaviour_compat6.sys.ini
#   inflating: administrator/language/en-GB/plg_system_accessibility.ini
#   inflating: administrator/language/en-GB/plg_fields_calendar.sys.ini
#   inflating: administrator/language/en-GB/plg_extension_joomla.ini
#   inflating: administrator/language/en-GB/plg_finder_newsfeeds.sys.ini
#   inflating: administrator/language/en-GB/plg_media-action_resize.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_users.ini
#   inflating: administrator/language/en-GB/plg_task_rotatelogs.ini
#   inflating: administrator/language/en-GB/plg_system_webauthn.sys.ini
#   inflating: administrator/language/en-GB/plg_privacy_contact.sys.ini
#   inflating: administrator/language/en-GB/com_plugins.ini
#   inflating: administrator/language/en-GB/plg_task_checkfiles.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_usergrouplist.ini
#   inflating: administrator/language/en-GB/plg_multifactorauth_yubikey.sys.ini
#   inflating: administrator/language/en-GB/plg_webservices_banners.sys.ini
#   inflating: administrator/language/en-GB/plg_finder_newsfeeds.ini
#   inflating: administrator/language/en-GB/plg_content_emailcloak.sys.ini
#   inflating: administrator/language/en-GB/plg_multifactorauth_email.sys.ini
#   inflating: administrator/language/en-GB/com_cpanel.ini
#   inflating: administrator/language/en-GB/plg_workflow_publishing.ini
#   inflating: administrator/language/en-GB/mod_privacy_dashboard.ini
#   inflating: administrator/language/en-GB/com_wrapper.sys.ini
#   inflating: administrator/language/en-GB/plg_task_checkfiles.ini
#   inflating: administrator/language/en-GB/plg_system_skipto.ini
#   inflating: administrator/language/en-GB/plg_system_actionlogs.ini
#   inflating: administrator/language/en-GB/com_config.sys.ini
#   inflating: administrator/language/en-GB/com_workflow.sys.ini
#   inflating: administrator/language/en-GB/plg_multifactorauth_email.ini
#   inflating: administrator/language/en-GB/com_checkin.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_color.ini
#   inflating: administrator/language/en-GB/com_scheduler.sys.ini
#   inflating: administrator/language/en-GB/plg_fields_sql.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_module.ini
#   inflating: administrator/language/en-GB/plg_system_remember.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_person.sys.ini
#   inflating: administrator/language/en-GB/mod_toolbar.ini
#   inflating: administrator/language/en-GB/mod_popular.ini
#   inflating: administrator/language/en-GB/plg_multifactorauth_webauthn.sys.ini
#   inflating: administrator/language/en-GB/plg_task_privacyconsent.ini
#   inflating: administrator/language/en-GB/plg_fields_imagelist.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_organization.ini
#   inflating: administrator/language/en-GB/mod_menu.sys.ini
#   inflating: administrator/language/en-GB/com_ajax.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_contacts_steps.ini
#   inflating: administrator/language/en-GB/plg_extension_namespacemap.sys.ini
#   inflating: administrator/language/en-GB/mod_menu.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_contacts.ini
#   inflating: administrator/language/en-GB/com_contact.sys.ini
#   inflating: administrator/language/en-GB/plg_schemaorg_organization.sys.ini
#   inflating: administrator/language/en-GB/plg_webservices_media.ini
#   inflating: administrator/language/en-GB/plg_webservices_privacy.sys.ini
#   inflating: administrator/language/en-GB/plg_workflow_publishing.sys.ini
#   inflating: administrator/language/en-GB/plg_user_contactcreator.sys.ini
#   inflating: administrator/language/en-GB/plg_installer_webinstaller.ini
#   inflating: administrator/language/en-GB/com_privacy.ini
#   inflating: administrator/language/en-GB/plg_filesystem_local.ini
#   inflating: administrator/language/en-GB/plg_editors-xtd_fields.sys.ini
#   inflating: administrator/language/en-GB/mod_privacy_status.sys.ini
#   inflating: administrator/language/en-GB/com_fields.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_smartsearch_steps.ini
#   inflating: administrator/language/en-GB/plg_behaviour_versionable.ini
#   inflating: administrator/language/en-GB/plg_content_fields.ini
#   inflating: administrator/language/en-GB/plg_fields_checkboxes.ini
#   inflating: administrator/language/en-GB/guidedtours.joomla_categories.ini
#   inflating: administrator/language/en-GB/plg_system_languagecode.sys.ini
#   inflating: administrator/language/en-GB/com_messages.ini
#   inflating: administrator/language/en-GB/plg_fields_list.ini
#   inflating: administrator/language/en-GB/mod_guidedtours.ini
#   inflating: administrator/language/en-GB/plg_system_schedulerunner.ini
#   inflating: administrator/language/en-GB/plg_content_vote.ini
#   inflating: administrator/language/en-GB/plg_fields_editor.ini
#   inflating: administrator/language/en-GB/plg_installer_packageinstaller.ini
#    creating: administrator/templates/
#    creating: administrator/templates/system/
#   inflating: administrator/templates/system/error.php
#   inflating: administrator/templates/system/index.php
#   inflating: administrator/templates/system/component.php
#    creating: administrator/templates/atum/
#   inflating: administrator/templates/atum/error_full.php
#   inflating: administrator/templates/atum/templateDetails.xml
#    creating: administrator/templates/atum/html/
#    creating: administrator/templates/atum/html/layouts/
#    creating: administrator/templates/atum/html/layouts/chromes/
#   inflating: administrator/templates/atum/html/layouts/chromes/title.php
#   inflating: administrator/templates/atum/html/layouts/chromes/header-item.php
#   inflating: administrator/templates/atum/html/layouts/chromes/well.php
#   inflating: administrator/templates/atum/html/layouts/chromes/body.php
#   inflating: administrator/templates/atum/html/layouts/status.php
#   inflating: administrator/templates/atum/error_login.php
#   inflating: administrator/templates/atum/login.php
#   inflating: administrator/templates/atum/cpanel.php
#   inflating: administrator/templates/atum/joomla.asset.json
#   inflating: administrator/templates/atum/error.php
#   inflating: administrator/templates/atum/index.php
#   inflating: administrator/templates/atum/component.php
#    creating: administrator/cache/
#   inflating: administrator/cache/index.html
#    creating: administrator/components/
#    creating: administrator/components/com_finder/
#    creating: administrator/components/com_finder/services/
#   inflating: administrator/components/com_finder/services/provider.php
#    creating: administrator/components/com_finder/src/
#    creating: administrator/components/com_finder/src/Controller/
#   inflating: administrator/components/com_finder/src/Controller/SearchesController.php
#   inflating: administrator/components/com_finder/src/Controller/IndexerController.php
#   inflating: administrator/components/com_finder/src/Controller/IndexController.php
#   inflating: administrator/components/com_finder/src/Controller/FiltersController.php
#   inflating: administrator/components/com_finder/src/Controller/DisplayController.php
#   inflating: administrator/components/com_finder/src/Controller/MapsController.php
#   inflating: administrator/components/com_finder/src/Controller/FilterController.php
#    creating: administrator/components/com_finder/src/Model/
#   inflating: administrator/components/com_finder/src/Model/SearchesModel.php
#   inflating: administrator/components/com_finder/src/Model/StatisticsModel.php
#   inflating: administrator/components/com_finder/src/Model/FilterModel.php
#   inflating: administrator/components/com_finder/src/Model/MapsModel.php
#   inflating: administrator/components/com_finder/src/Model/IndexModel.php
#   inflating: administrator/components/com_finder/src/Model/ItemModel.php
#   inflating: administrator/components/com_finder/src/Model/FiltersModel.php
#   inflating: administrator/components/com_finder/src/Model/IndexerModel.php
#    creating: administrator/components/com_finder/src/View/
#    creating: administrator/components/com_finder/src/View/Item/
#   inflating: administrator/components/com_finder/src/View/Item/HtmlView.php
#    creating: administrator/components/com_finder/src/View/Filters/
#   inflating: administrator/components/com_finder/src/View/Filters/HtmlView.php
#    creating: administrator/components/com_finder/src/View/Searches/
#   inflating: administrator/components/com_finder/src/View/Searches/HtmlView.php
#    creating: administrator/components/com_finder/src/View/Index/
#   inflating: administrator/components/com_finder/src/View/Index/HtmlView.php
#    creating: administrator/components/com_finder/src/View/Indexer/
#   inflating: administrator/components/com_finder/src/View/Indexer/HtmlView.php
#    creating: administrator/components/com_finder/src/View/Filter/
#   inflating: administrator/components/com_finder/src/View/Filter/HtmlView.php
#    creating: administrator/components/com_finder/src/View/Statistics/
#   inflating: administrator/components/com_finder/src/View/Statistics/HtmlView.php
#    creating: administrator/components/com_finder/src/View/Maps/
#   inflating: administrator/components/com_finder/src/View/Maps/HtmlView.php
#    creating: administrator/components/com_finder/src/Service/
#    creating: administrator/components/com_finder/src/Service/HTML/
#   inflating: administrator/components/com_finder/src/Service/HTML/Finder.php
#   inflating: administrator/components/com_finder/src/Service/HTML/Query.php
#   inflating: administrator/components/com_finder/src/Service/HTML/Filter.php
#    creating: administrator/components/com_finder/src/Helper/
#   inflating: administrator/components/com_finder/src/Helper/FinderHelper.php
#   inflating: administrator/components/com_finder/src/Helper/LanguageHelper.php
#    creating: administrator/components/com_finder/src/Field/
#   inflating: administrator/components/com_finder/src/Field/ContentmapField.php
#   inflating: administrator/components/com_finder/src/Field/ContenttypesField.php
#   inflating: administrator/components/com_finder/src/Field/BranchesField.php
#   inflating: administrator/components/com_finder/src/Field/TaxonomytypesField.php
#   inflating: administrator/components/com_finder/src/Field/SearchfilterField.php
#    creating: administrator/components/com_finder/src/Table/
#   inflating: administrator/components/com_finder/src/Table/LinkTable.php
#   inflating: administrator/components/com_finder/src/Table/FilterTable.php
#   inflating: administrator/components/com_finder/src/Table/MapTable.php
#    creating: administrator/components/com_finder/src/Extension/
#   inflating: administrator/components/com_finder/src/Extension/FinderComponent.php
#    creating: administrator/components/com_finder/src/Response/
#   inflating: administrator/components/com_finder/src/Response/Response.php
#    creating: administrator/components/com_finder/src/Indexer/
#    creating: administrator/components/com_finder/src/Indexer/Parser/
#   inflating: administrator/components/com_finder/src/Indexer/Parser/Txt.php
#   inflating: administrator/components/com_finder/src/Indexer/Parser/Rtf.php
#   inflating: administrator/components/com_finder/src/Indexer/Parser/Html.php
#   inflating: administrator/components/com_finder/src/Indexer/DebugAdapter.php
#   inflating: administrator/components/com_finder/src/Indexer/DebugIndexer.php
#   inflating: administrator/components/com_finder/src/Indexer/Adapter.php
#   inflating: administrator/components/com_finder/src/Indexer/Helper.php
#   inflating: administrator/components/com_finder/src/Indexer/Query.php
#   inflating: administrator/components/com_finder/src/Indexer/Language.php
#   inflating: administrator/components/com_finder/src/Indexer/Token.php
#   inflating: administrator/components/com_finder/src/Indexer/Indexer.php
#   inflating: administrator/components/com_finder/src/Indexer/Result.php
#    creating: administrator/components/com_finder/src/Indexer/Language/
#   inflating: administrator/components/com_finder/src/Indexer/Language/Zh.php
#   inflating: administrator/components/com_finder/src/Indexer/Language/El.php
#   inflating: administrator/components/com_finder/src/Indexer/Parser.php
#   inflating: administrator/components/com_finder/src/Indexer/Taxonomy.php
#    creating: administrator/components/com_finder/forms/
#   inflating: administrator/components/com_finder/forms/indexer.xml
#   inflating: administrator/components/com_finder/forms/filter_index.xml
#   inflating: administrator/components/com_finder/forms/filter_maps.xml
#   inflating: administrator/components/com_finder/forms/filter_filters.xml
#   inflating: administrator/components/com_finder/forms/filter_searches.xml
#   inflating: administrator/components/com_finder/forms/filter.xml
#   inflating: administrator/components/com_finder/config.xml
#    creating: administrator/components/com_finder/sql/
#   inflating: administrator/components/com_finder/sql/uninstall.mysql.sql
#   inflating: administrator/components/com_finder/sql/install.postgresql.sql
#   inflating: administrator/components/com_finder/sql/uninstall.postgresql.sql
#   inflating: administrator/components/com_finder/sql/install.mysql.sql
#   inflating: administrator/components/com_finder/finder.xml
#    creating: administrator/components/com_finder/helpers/
#   inflating: administrator/components/com_finder/helpers/language.php
#    creating: administrator/components/com_finder/tmpl/
#    creating: administrator/components/com_finder/tmpl/searches/
#   inflating: administrator/components/com_finder/tmpl/searches/emptystate.php
#   inflating: administrator/components/com_finder/tmpl/searches/default.php
#   inflating: administrator/components/com_finder/tmpl/searches/default.xml
#    creating: administrator/components/com_finder/tmpl/statistics/
#   inflating: administrator/components/com_finder/tmpl/statistics/default.php
#   inflating: administrator/components/com_finder/tmpl/statistics/default.xml
#    creating: administrator/components/com_finder/tmpl/index/
#   inflating: administrator/components/com_finder/tmpl/index/emptystate.php
#   inflating: administrator/components/com_finder/tmpl/index/default.php
#   inflating: administrator/components/com_finder/tmpl/index/default.xml
#    creating: administrator/components/com_finder/tmpl/indexer/
#   inflating: administrator/components/com_finder/tmpl/indexer/debug.php
#   inflating: administrator/components/com_finder/tmpl/indexer/default.php
#    creating: administrator/components/com_finder/tmpl/filters/
#   inflating: administrator/components/com_finder/tmpl/filters/emptystate.php
#   inflating: administrator/components/com_finder/tmpl/filters/default.php
#   inflating: administrator/components/com_finder/tmpl/filters/default.xml
#    creating: administrator/components/com_finder/tmpl/item/
#   inflating: administrator/components/com_finder/tmpl/item/default.php
#    creating: administrator/components/com_finder/tmpl/maps/
#   inflating: administrator/components/com_finder/tmpl/maps/emptystate.php
#   inflating: administrator/components/com_finder/tmpl/maps/default.php
#   inflating: administrator/components/com_finder/tmpl/maps/default.xml
#    creating: administrator/components/com_finder/tmpl/filter/
#   inflating: administrator/components/com_finder/tmpl/filter/edit.php
#   inflating: administrator/components/com_finder/access.xml
#    creating: administrator/components/com_associations/
#    creating: administrator/components/com_associations/services/
#   inflating: administrator/components/com_associations/services/provider.php
#   inflating: administrator/components/com_associations/associations.xml
#    creating: administrator/components/com_associations/src/
#    creating: administrator/components/com_associations/src/Controller/
#   inflating: administrator/components/com_associations/src/Controller/DisplayController.php
#   inflating: administrator/components/com_associations/src/Controller/AssociationController.php
#   inflating: administrator/components/com_associations/src/Controller/AssociationsController.php
#    creating: administrator/components/com_associations/src/Model/
#   inflating: administrator/components/com_associations/src/Model/AssociationModel.php
#   inflating: administrator/components/com_associations/src/Model/AssociationsModel.php
#    creating: administrator/components/com_associations/src/View/
#    creating: administrator/components/com_associations/src/View/Associations/
#   inflating: administrator/components/com_associations/src/View/Associations/HtmlView.php
#    creating: administrator/components/com_associations/src/View/Association/
#   inflating: administrator/components/com_associations/src/View/Association/HtmlView.php
#    creating: administrator/components/com_associations/src/Helper/
#   inflating: administrator/components/com_associations/src/Helper/AssociationsHelper.php
#    creating: administrator/components/com_associations/src/Field/
#   inflating: administrator/components/com_associations/src/Field/ItemtypeField.php
#   inflating: administrator/components/com_associations/src/Field/ItemlanguageField.php
#    creating: administrator/components/com_associations/src/Field/Modal/
#   inflating: administrator/components/com_associations/src/Field/Modal/AssociationField.php
#    creating: administrator/components/com_associations/src/Dispatcher/
#   inflating: administrator/components/com_associations/src/Dispatcher/Dispatcher.php
#    creating: administrator/components/com_associations/layouts/
#    creating: administrator/components/com_associations/layouts/joomla/
#    creating: administrator/components/com_associations/layouts/joomla/searchtools/
#   inflating: administrator/components/com_associations/layouts/joomla/searchtools/default.php
#    creating: administrator/components/com_associations/forms/
#   inflating: administrator/components/com_associations/forms/association.xml
#   inflating: administrator/components/com_associations/forms/filter_associations.xml
#   inflating: administrator/components/com_associations/config.xml
#    creating: administrator/components/com_associations/tmpl/
#    creating: administrator/components/com_associations/tmpl/associations/
#   inflating: administrator/components/com_associations/tmpl/associations/default.php
# ...
#   inflating: plugins/task/deleteactionlogs/forms/deleteForm.xml
#   inflating: plugins/task/deleteactionlogs/deleteactionlogs.xml
#    creating: plugins/task/updatenotification/
#    creating: plugins/task/updatenotification/services/
#   inflating: plugins/task/updatenotification/services/provider.php
#    creating: plugins/task/updatenotification/src/
#    creating: plugins/task/updatenotification/src/Extension/
#   inflating: plugins/task/updatenotification/src/Extension/UpdateNotification.php
#    creating: plugins/task/updatenotification/forms/
#   inflating: plugins/task/updatenotification/forms/sendForm.xml
#   inflating: plugins/task/updatenotification/updatenotification.xml
#    creating: plugins/user/
#    creating: plugins/user/contactcreator/
#    creating: plugins/user/contactcreator/services/
#   inflating: plugins/user/contactcreator/services/provider.php
#    creating: plugins/user/contactcreator/src/
#    creating: plugins/user/contactcreator/src/Extension/
#   inflating: plugins/user/contactcreator/src/Extension/ContactCreator.php
#   inflating: plugins/user/contactcreator/contactcreator.xml
#    creating: plugins/user/terms/
#    creating: plugins/user/terms/services/
#   inflating: plugins/user/terms/services/provider.php
#    creating: plugins/user/terms/src/
#    creating: plugins/user/terms/src/Field/
#   inflating: plugins/user/terms/src/Field/TermsField.php
#    creating: plugins/user/terms/src/Extension/
#   inflating: plugins/user/terms/src/Extension/Terms.php
#    creating: plugins/user/terms/forms/
#   inflating: plugins/user/terms/forms/terms.xml
#   inflating: plugins/user/terms/terms.xml
#    creating: plugins/user/token/
#    creating: plugins/user/token/services/
#   inflating: plugins/user/token/services/provider.php
#    creating: plugins/user/token/src/
#    creating: plugins/user/token/src/Field/
#   inflating: plugins/user/token/src/Field/JoomlatokenField.php
#    creating: plugins/user/token/src/Extension/
#   inflating: plugins/user/token/src/Extension/Token.php
#    creating: plugins/user/token/forms/
#   inflating: plugins/user/token/forms/token.xml
#   inflating: plugins/user/token/token.xml
#    creating: plugins/user/profile/
#    creating: plugins/user/profile/services/
#   inflating: plugins/user/profile/services/provider.php
#   inflating: plugins/user/profile/profile.xml
#    creating: plugins/user/profile/src/
#    creating: plugins/user/profile/src/Field/
#   inflating: plugins/user/profile/src/Field/TosField.php
#    creating: plugins/user/profile/src/Extension/
#   inflating: plugins/user/profile/src/Extension/Profile.php
#    creating: plugins/user/profile/forms/
#   inflating: plugins/user/profile/forms/profile.xml
#    creating: plugins/user/joomla/
#    creating: plugins/user/joomla/services/
#   inflating: plugins/user/joomla/services/provider.php
#   inflating: plugins/user/joomla/joomla.xml
#    creating: plugins/user/joomla/src/
#    creating: plugins/user/joomla/src/Extension/
#   inflating: plugins/user/joomla/src/Extension/Joomla.php
#    creating: plugins/schemaorg/
#    creating: plugins/schemaorg/book/
#    creating: plugins/schemaorg/book/services/
#   inflating: plugins/schemaorg/book/services/provider.php
#    creating: plugins/schemaorg/book/src/
#    creating: plugins/schemaorg/book/src/Extension/
#   inflating: plugins/schemaorg/book/src/Extension/Book.php
#    creating: plugins/schemaorg/book/forms/
#   inflating: plugins/schemaorg/book/forms/schemaorg.xml
#   inflating: plugins/schemaorg/book/book.xml
#    creating: plugins/schemaorg/blogposting/
#    creating: plugins/schemaorg/blogposting/services/
#   inflating: plugins/schemaorg/blogposting/services/provider.php
#    creating: plugins/schemaorg/blogposting/src/
#    creating: plugins/schemaorg/blogposting/src/Extension/
#   inflating: plugins/schemaorg/blogposting/src/Extension/BlogPosting.php
#    creating: plugins/schemaorg/blogposting/forms/
#   inflating: plugins/schemaorg/blogposting/forms/schemaorg.xml
#   inflating: plugins/schemaorg/blogposting/blogposting.xml
#    creating: plugins/schemaorg/event/
#    creating: plugins/schemaorg/event/services/
#   inflating: plugins/schemaorg/event/services/provider.php
#    creating: plugins/schemaorg/event/src/
#    creating: plugins/schemaorg/event/src/Extension/
#   inflating: plugins/schemaorg/event/src/Extension/Event.php
#    creating: plugins/schemaorg/event/forms/
#   inflating: plugins/schemaorg/event/forms/schemaorg.xml
#   inflating: plugins/schemaorg/event/event.xml
#    creating: plugins/schemaorg/recipe/
#    creating: plugins/schemaorg/recipe/services/
#   inflating: plugins/schemaorg/recipe/services/provider.php
#    creating: plugins/schemaorg/recipe/src/
#    creating: plugins/schemaorg/recipe/src/Extension/
#   inflating: plugins/schemaorg/recipe/src/Extension/Recipe.php
#    creating: plugins/schemaorg/recipe/forms/
#   inflating: plugins/schemaorg/recipe/forms/schemaorg.xml
#   inflating: plugins/schemaorg/recipe/forms/duration.xml
#   inflating: plugins/schemaorg/recipe/recipe.xml
#    creating: plugins/schemaorg/jobposting/
#    creating: plugins/schemaorg/jobposting/services/
#   inflating: plugins/schemaorg/jobposting/services/provider.php
#    creating: plugins/schemaorg/jobposting/src/
#    creating: plugins/schemaorg/jobposting/src/Extension/
#   inflating: plugins/schemaorg/jobposting/src/Extension/JobPosting.php
#    creating: plugins/schemaorg/jobposting/forms/
#   inflating: plugins/schemaorg/jobposting/forms/schemaorg.xml
#   inflating: plugins/schemaorg/jobposting/jobposting.xml
#    creating: plugins/schemaorg/person/
#    creating: plugins/schemaorg/person/services/
#   inflating: plugins/schemaorg/person/services/provider.php
#    creating: plugins/schemaorg/person/src/
#    creating: plugins/schemaorg/person/src/Extension/
#   inflating: plugins/schemaorg/person/src/Extension/Person.php
#    creating: plugins/schemaorg/person/forms/
#   inflating: plugins/schemaorg/person/forms/schemaorg.xml
#   inflating: plugins/schemaorg/person/person.xml
#    creating: plugins/schemaorg/article/
#    creating: plugins/schemaorg/article/services/
#   inflating: plugins/schemaorg/article/services/provider.php
#    creating: plugins/schemaorg/article/src/
#    creating: plugins/schemaorg/article/src/Extension/
#   inflating: plugins/schemaorg/article/src/Extension/Article.php
#   inflating: plugins/schemaorg/article/article.xml
#    creating: plugins/schemaorg/article/forms/
#   inflating: plugins/schemaorg/article/forms/schemaorg.xml
#    creating: plugins/schemaorg/custom/
#    creating: plugins/schemaorg/custom/services/
#   inflating: plugins/schemaorg/custom/services/provider.php
#   inflating: plugins/schemaorg/custom/custom.xml
#    creating: plugins/schemaorg/custom/src/
#    creating: plugins/schemaorg/custom/src/Extension/
#   inflating: plugins/schemaorg/custom/src/Extension/Custom.php
#    creating: plugins/schemaorg/custom/forms/
#   inflating: plugins/schemaorg/custom/forms/schemaorg.xml
#    creating: plugins/schemaorg/organization/
#    creating: plugins/schemaorg/organization/services/
#   inflating: plugins/schemaorg/organization/services/provider.php
#    creating: plugins/schemaorg/organization/src/
#    creating: plugins/schemaorg/organization/src/Extension/
#   inflating: plugins/schemaorg/organization/src/Extension/Organization.php
#    creating: plugins/schemaorg/organization/forms/
#   inflating: plugins/schemaorg/organization/forms/schemaorg.xml
#   inflating: plugins/schemaorg/organization/organization.xml
#    creating: plugins/sampledata/
#    creating: plugins/sampledata/multilang/
#    creating: plugins/sampledata/multilang/services/
#   inflating: plugins/sampledata/multilang/services/provider.php
#    creating: plugins/sampledata/multilang/src/
#    creating: plugins/sampledata/multilang/src/Extension/
#   inflating: plugins/sampledata/multilang/src/Extension/MultiLanguage.php
#   inflating: plugins/sampledata/multilang/multilang.xml
#    creating: plugins/sampledata/blog/
#   inflating: plugins/sampledata/blog/blog.xml
#    creating: plugins/sampledata/blog/services/
#   inflating: plugins/sampledata/blog/services/provider.php
#    creating: plugins/sampledata/blog/src/
#    creating: plugins/sampledata/blog/src/Extension/
#   inflating: plugins/sampledata/blog/src/Extension/Blog.php
#   inflating: plugins/index.html
#    creating: plugins/privacy/
#    creating: plugins/privacy/contact/
#    creating: plugins/privacy/contact/services/
#   inflating: plugins/privacy/contact/services/provider.php
#    creating: plugins/privacy/contact/src/
#    creating: plugins/privacy/contact/src/Extension/
#   inflating: plugins/privacy/contact/src/Extension/Contact.php
#   inflating: plugins/privacy/contact/contact.xml
#    creating: plugins/privacy/content/
#    creating: plugins/privacy/content/services/
#   inflating: plugins/privacy/content/services/provider.php
#    creating: plugins/privacy/content/src/
#    creating: plugins/privacy/content/src/Extension/
#   inflating: plugins/privacy/content/src/Extension/Content.php
#   inflating: plugins/privacy/content/content.xml
#    creating: plugins/privacy/message/
#    creating: plugins/privacy/message/services/
#   inflating: plugins/privacy/message/services/provider.php
#    creating: plugins/privacy/message/src/
#    creating: plugins/privacy/message/src/Extension/
#   inflating: plugins/privacy/message/src/Extension/Message.php
#   inflating: plugins/privacy/message/message.xml
#    creating: plugins/privacy/actionlogs/
#    creating: plugins/privacy/actionlogs/services/
#   inflating: plugins/privacy/actionlogs/services/provider.php
#    creating: plugins/privacy/actionlogs/src/
#    creating: plugins/privacy/actionlogs/src/Extension/
#   inflating: plugins/privacy/actionlogs/src/Extension/Actionlogs.php
#   inflating: plugins/privacy/actionlogs/actionlogs.xml
#    creating: plugins/privacy/user/
#    creating: plugins/privacy/user/services/
#   inflating: plugins/privacy/user/services/provider.php
#    creating: plugins/privacy/user/src/
#    creating: plugins/privacy/user/src/Extension/
#   inflating: plugins/privacy/user/src/Extension/UserPlugin.php
#   inflating: plugins/privacy/user/user.xml
#    creating: plugins/privacy/consents/
#    creating: plugins/privacy/consents/services/
#   inflating: plugins/privacy/consents/services/provider.php
#    creating: plugins/privacy/consents/src/
#    creating: plugins/privacy/consents/src/Extension/
#   inflating: plugins/privacy/consents/src/Extension/Consents.php
#   inflating: plugins/privacy/consents/consents.xml
#    creating: plugins/editors-xtd/
#    creating: plugins/editors-xtd/module/
#    creating: plugins/editors-xtd/module/services/
#   inflating: plugins/editors-xtd/module/services/provider.php
#    creating: plugins/editors-xtd/module/src/
#    creating: plugins/editors-xtd/module/src/Extension/
#   inflating: plugins/editors-xtd/module/src/Extension/Module.php
#   inflating: plugins/editors-xtd/module/module.xml
#    creating: plugins/editors-xtd/menu/
#    creating: plugins/editors-xtd/menu/services/
#   inflating: plugins/editors-xtd/menu/services/provider.php
#    creating: plugins/editors-xtd/menu/src/
#    creating: plugins/editors-xtd/menu/src/Extension/
#   inflating: plugins/editors-xtd/menu/src/Extension/Menu.php
#   inflating: plugins/editors-xtd/menu/menu.xml
#    creating: plugins/editors-xtd/contact/
#    creating: plugins/editors-xtd/contact/services/
#   inflating: plugins/editors-xtd/contact/services/provider.php
#    creating: plugins/editors-xtd/contact/src/
#    creating: plugins/editors-xtd/contact/src/Extension/
#   inflating: plugins/editors-xtd/contact/src/Extension/Contact.php
#   inflating: plugins/editors-xtd/contact/contact.xml
#    creating: plugins/editors-xtd/fields/
#    creating: plugins/editors-xtd/fields/services/
#   inflating: plugins/editors-xtd/fields/services/provider.php
#    creating: plugins/editors-xtd/fields/src/
#    creating: plugins/editors-xtd/fields/src/Extension/
#   inflating: plugins/editors-xtd/fields/src/Extension/Fields.php
#   inflating: plugins/editors-xtd/fields/fields.xml
#    creating: plugins/editors-xtd/image/
#    creating: plugins/editors-xtd/image/services/
#   inflating: plugins/editors-xtd/image/services/provider.php
#    creating: plugins/editors-xtd/image/src/
#    creating: plugins/editors-xtd/image/src/Extension/
#   inflating: plugins/editors-xtd/image/src/Extension/Image.php
#   inflating: plugins/editors-xtd/image/image.xml
#    creating: plugins/editors-xtd/article/
#    creating: plugins/editors-xtd/article/services/
#   inflating: plugins/editors-xtd/article/services/provider.php
#    creating: plugins/editors-xtd/article/src/
#    creating: plugins/editors-xtd/article/src/Extension/
#   inflating: plugins/editors-xtd/article/src/Extension/Article.php
#   inflating: plugins/editors-xtd/article/article.xml
#    creating: plugins/editors-xtd/readmore/
#    creating: plugins/editors-xtd/readmore/services/
#   inflating: plugins/editors-xtd/readmore/services/provider.php
#    creating: plugins/editors-xtd/readmore/src/
#    creating: plugins/editors-xtd/readmore/src/Extension/
#   inflating: plugins/editors-xtd/readmore/src/Extension/ReadMore.php
#   inflating: plugins/editors-xtd/readmore/readmore.xml
#    creating: plugins/editors-xtd/pagebreak/
#    creating: plugins/editors-xtd/pagebreak/services/
#   inflating: plugins/editors-xtd/pagebreak/services/provider.php
#    creating: plugins/editors-xtd/pagebreak/src/
#    creating: plugins/editors-xtd/pagebreak/src/Extension/
#   inflating: plugins/editors-xtd/pagebreak/src/Extension/PageBreak.php
#   inflating: plugins/editors-xtd/pagebreak/pagebreak.xml
#   inflating: robots.txt.dist
#    creating: templates/
#    creating: templates/system/
#   inflating: templates/system/offline.php
#   inflating: templates/system/incompatible.html
#   inflating: templates/system/error.php
#   inflating: templates/system/index.php
#   inflating: templates/system/fatal-error.html
#   inflating: templates/system/component.php
#   inflating: templates/system/build_incomplete.html
#   inflating: templates/system/fatal.php
#    creating: templates/cassiopeia_extended/
#   inflating: templates/cassiopeia_extended/templateDetails.xml
#    creating: templates/cassiopeia_extended/html/
#   inflating: templates/cassiopeia_extended/html/index.html
#   inflating: templates/cassiopeia_extended/offline.php
#   inflating: templates/cassiopeia_extended/error.php
#   inflating: templates/cassiopeia_extended/index.php
#   inflating: templates/cassiopeia_extended/component.php
#    creating: templates/cassiopeia/
#   inflating: templates/cassiopeia/templateDetails.xml
#    creating: templates/cassiopeia/html/
#    creating: templates/cassiopeia/html/mod_custom/
#   inflating: templates/cassiopeia/html/mod_custom/banner.php
#    creating: templates/cassiopeia/html/layouts/
#    creating: templates/cassiopeia/html/layouts/chromes/
#   inflating: templates/cassiopeia/html/layouts/chromes/card.php
#   inflating: templates/cassiopeia/html/layouts/chromes/noCard.php
#    creating: templates/cassiopeia/html/mod_menu/
#   inflating: templates/cassiopeia/html/mod_menu/dropdown-metismenu_url.php
#   inflating: templates/cassiopeia/html/mod_menu/dropdown-metismenu_heading.php
#   inflating: templates/cassiopeia/html/mod_menu/collapse-metismenu.php
#   inflating: templates/cassiopeia/html/mod_menu/dropdown-metismenu_component.php
#   inflating: templates/cassiopeia/html/mod_menu/dropdown-metismenu.php
#   inflating: templates/cassiopeia/html/mod_menu/dropdown-metismenu_separator.php
#    creating: templates/cassiopeia/html/tinymce/
#   inflating: templates/cassiopeia/html/tinymce/index.html
#   inflating: templates/cassiopeia/offline.php
#   inflating: templates/cassiopeia/joomla.asset.json
#   inflating: templates/cassiopeia/error.php
#   inflating: templates/cassiopeia/index.php
#   inflating: templates/cassiopeia/component.php
#   inflating: templates/index.html
#    creating: tmp/
#   inflating: tmp/index.html
#   inflating: web.config.txt
# ServerName을 입력하세요. (예: test.com , ppp.com):  test.com
# 사용할 DNS의 ip:  172.16.16.25
# httpd restart 시작
#
# [JL] 설정 완료
